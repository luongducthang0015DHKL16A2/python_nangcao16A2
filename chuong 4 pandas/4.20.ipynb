# %%
import numpy as np
import pandas as pd

# %%
data_euro12=pd.read_csv('./euro2012.csv')
print(data_euro12)
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
df_euro12=pd.DataFrame(data_euro12)
df_euro12
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
print("type:",df_euro12.dtypes)
print("shape:",df_euro12.shape)
print('danh sachs cac cot:',list(df_euro12.columns))
df_euro12
# Out:
# type: Unnamed: 0                      int64
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy              object
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# ...

# %%
# 1.in gia tri cot goals
df_euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#2. co bao nhieu doi tham gia euro 2012
print("numbers of team:",len(df_euro12['Team']),'team')
# Out:
# numbers of team: 16 team

# %%
#3.in thong tin cua euro 2012
print(df_euro12)
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
#4.tạo một dataFrame mới từ dataframe 
discipline=df_euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#5. sắp xếp giảm dần theo 2 cột yellow và red
discipline.sort_values(['Yellow Cards'], ascending=[False])
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 6                Greece             9          1
# 1        Czech Republic             7          0
# 9                Poland             7          1
# 14               Sweden             7          0
# 4                France             6          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
discipline.sort_values(['Red Cards'], ascending=[False])
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 10             Portugal            12          0
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#6a.tính trung bình Yellow Cards
tb_vang=discipline['Yellow Cards'].mean()
tb_vang
# Out:
# 7.4375

# %%
#6b loc ca doi ghi hơn 6 bàn thắng
goals_6=df_euro12[df_euro12['Goals']>6]
goals_6
# Out:
#     Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5            5  Germany     10               32                32
# 13          13    Spain     12               42                33
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5             47.80%           15.60%                          80
# 13            55.90%           16.00%                         100
#
#     Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5              2              1  ...          10                62.60%
# 13             0              1  ...          15                93.80%
#
#     Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5          63              49       12             4          0       15
# 13        102              83       19            11          0       17
#
#     Subs off  Players Used
# 5         15            17
# 13        17            18
#
# [2 rows x 36 columns]

# %%
7.#in các đội mà tên bắt đầu bằng 'G'
G_teams=df_euro12[df_euro12['Team'].str.startswith('G')]
G_teams
# Out:
#    Unnamed: 0     Team  Goals  Shots on target  Shots off target  \
# 5           5  Germany     10               32                32
# 6           6   Greece      5                8                18
#
#   Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 5            47.80%           15.60%                          80
# 6            30.70%           19.20%                          32
#
#    Hit Woodwork  Penalty goals  ...  Saves made  Saves-to-shots ratio  \
# 5             2              1  ...          10                62.60%
# 6             1              1  ...          13                65.10%
#
#    Fouls Won  Fouls Conceded Offsides  Yellow Cards  Red Cards  Subs on  \
# 5         63              49       12             4          0       15
# 6         67              48       12             9          1       12
#
#    Subs off  Players Used
# 5        15            17
# 6        12            20
#
# [2 rows x 36 columns]

# %%
#in 7 cột đầu của euro12
print(df_euro12.iloc[:,:7])
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
#in tất cả các cột trừ 3 cột cuối
df_euro12.iloc[:,:-3]
# Out:
#     Unnamed: 0                 Team  Goals  Shots on target  Shots off target  \
# 0            0              Croatia      4               13                12
# 1            1       Czech Republic      4               13                18
# 2            2              Denmark      4               10                10
# 3            3              England      5               11                18
# 4            4               France      3               22                24
# 5            5              Germany     10               32                32
# 6            6               Greece      5                8                18
# 7            7                Italy      6               34                45
# 8            8          Netherlands      2               12                36
# 9            9               Poland      2               15                23
# 10          10             Portugal      6               22                42
# ...

# %%
#10.in các cột Teams, goals,shooting Accurary, yellow cards, red cards
df_euro12[['Team','Goals','Shooting Accuracy','Yellow Cards','Red Cards']]
# Out:
#                    Team  Goals Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia      4            51.90%             9          0
# 1        Czech Republic      4            41.90%             7          0
# 2               Denmark      4            50.00%             4          0
# 3               England      5            50.00%             5          0
# 4                France      3            37.90%             6          0
# 5               Germany     10            47.80%             4          0
# 6                Greece      5            30.70%             9          1
# 7                 Italy      6            43.00%            16          0
# 8           Netherlands      2            25.00%             5          0
# 9                Poland      2            39.40%             7          1
# 10             Portugal      6            34.30%            12          0
# 11  Republic of Ireland      1            36.80%             6          1
# ...

# %%
#11 in cac cot chi hien thi team, shooting accuracy tu england,italy,russia
df_euro12[df_euro12['Team'].isin(['England','Italy','Russia'])][['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%

# %%
df_euro12.loc[[3,7,12],['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%
